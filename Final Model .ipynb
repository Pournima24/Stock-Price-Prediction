# %% [markdown]
# ### Libraries

# %%
# pip install yfinance

# %%
import numpy as np
import pandas as pd


# Libraries for Data extraction 
from datetime import datetime
import yfinance as yf


#Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns

#Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Data Extraction

# %% [markdown]
# Objective is to get the data of RELIANCE INDUSTRIES from 01/01/2015 to till date.
#
# Columns required are Open,High,Low,Close

# %%
# Defining Parameters
start_date = datetime(2015,1,1)
end_date = datetime.today()

#Data downloading
data = yf.download('RELIANCE.NS',start=start_date,end=end_date)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01   438.988831   441.812073   437.676270   439.781311   417.988892
# 2015-01-02   439.880371   443.818054   437.998199   438.617340   416.882599
# 2015-01-05   438.344940   441.267212   432.946106   433.812897   412.316284
# 2015-01-06   430.915344   432.401276   412.093750   414.124512   393.603546
# 2015-01-07   414.619812   425.367950   414.570282   423.139069   402.171326
# ...                 ...          ...          ...          ...          ...
# 2023-02-07  2312.000000  2327.399902  2293.000000  2305.899902  2305.899902
# 2023-02-08  2313.000000  2359.899902  2307.000000  2351.949951  2351.949951
# 2023-02-09  2353.449951  2370.850098  2334.000000  2356.050049  2356.050049
# 2023-02-10  2354.899902  2354.899902  2321.300049  2336.649902  2336.649902
# 2023-02-13  2340.199951  2350.000000  2313.550049  2323.350098  2323.350098
#
#              Volume
# Date
# 2015-01-01  1367720
# 2015-01-02  3383424
# 2015-01-05  4662967
# 2015-01-06  8596809
# 2015-01-07  9562421
# ...             ...
# 2023-02-07  6985001
# 2023-02-08  9765490
# 2023-02-09  6079228
# 2023-02-10  4979789
# 2023-02-13  4776921
#
# [2006 rows x 6 columns]

# %%
data.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-01-01  438.988831  441.812073  437.676270  439.781311  417.988892
# 2015-01-02  439.880371  443.818054  437.998199  438.617340  416.882599
# 2015-01-05  438.344940  441.267212  432.946106  433.812897  412.316284
# 2015-01-06  430.915344  432.401276  412.093750  414.124512  393.603546
# 2015-01-07  414.619812  425.367950  414.570282  423.139069  402.171326
#
#              Volume
# Date
# 2015-01-01  1367720
# 2015-01-02  3383424
# 2015-01-05  4662967
# 2015-01-06  8596809
# 2015-01-07  9562421

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-02-07  2312.000000  2327.399902  2293.000000  2305.899902  2305.899902
# 2023-02-08  2313.000000  2359.899902  2307.000000  2351.949951  2351.949951
# 2023-02-09  2353.449951  2370.850098  2334.000000  2356.050049  2356.050049
# 2023-02-10  2354.899902  2354.899902  2321.300049  2336.649902  2336.649902
# 2023-02-13  2340.199951  2350.000000  2313.550049  2323.350098  2323.350098
#
#              Volume
# Date
# 2023-02-07  6985001
# 2023-02-08  9765490
# 2023-02-09  6079228
# 2023-02-10  4979789
# 2023-02-13  4776921

# %%
data.drop({'Adj Close','Volume','Open','High','Low'},axis=1,inplace = True)
data
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2023-02-07  2305.899902
# 2023-02-08  2351.949951
# 2023-02-09  2356.050049
# 2023-02-10  2336.649902
# 2023-02-13  2323.350098
#
# [2006 rows x 1 columns]

# %% [markdown]
# ### EDA

# %%
data.head()
# Out:
#                  Close
# Date
# 2015-01-01  439.781311
# 2015-01-02  438.617340
# 2015-01-05  433.812897
# 2015-01-06  414.124512
# 2015-01-07  423.139069

# %%
data.tail()
# Out:
#                   Close
# Date
# 2023-02-07  2305.899902
# 2023-02-08  2351.949951
# 2023-02-09  2356.050049
# 2023-02-10  2336.649902
# 2023-02-13  2323.350098

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2006 entries, 2015-01-01 to 2023-02-13
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2006 non-null   float64
# dtypes: float64(1)
# memory usage: 31.3 KB

# %%
data.isna().sum()
# Out:
# Close    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 59

# %%
data.describe()
# Out:
#              Close
# count  2006.000000
# mean   1331.564239
# std     758.214404
# min     401.568542
# 25%     533.672562
# 50%    1192.669678
# 75%    2077.224976
# max    2819.850098

# %% [markdown]
# Correlation matrix shows that data is highly correlated.

# %%
#Distplots to check the distribution of data

plt.figure(figsize=(17,15))
plt.subplot(4,1,4)
sns.distplot(data['Close'])
plt.title("Reliance stock Close Prices")
# Out:
# Text(0.5, 1.0, 'Reliance stock Close Prices')

# %% [markdown]
# #### To check normality of the data
# Shapiro test(p-value > 0.05 -- Normally distributed data)

# %%
from scipy import stats

shapiro_test = stats.shapiro(data)
print('stats= ', shapiro_test.statistic,'\npvalue = ',shapiro_test.pvalue)
# Out:
# stats=  0.892225980758667
# pvalue =  2.52411123928311e-35

# %%
# QQ Plot

import statsmodels.api as sm

sm.qqplot(data['Close'], line='q')
plt.title('Close')
# Out:
# Text(0.5, 1.0, 'Close')

# %%
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20c9ee4d190>,
#   <matplotlib.lines.Line2D at 0x20c9ee4d460>],
#  'caps': [<matplotlib.lines.Line2D at 0x20c9ee4d730>,
#   <matplotlib.lines.Line2D at 0x20c9ee4da00>],
#  'boxes': [<matplotlib.lines.Line2D at 0x20c9ee3ce80>],
#  'medians': [<matplotlib.lines.Line2D at 0x20c9ee4dcd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20c9ee4dfa0>],
#  'means': []}

# %% [markdown]
# Since pvalue < 0.05 & from the QQ plot, we can infer that data is not normally distributed

# %% [markdown]
# Hence to make data normally distributed we need to do minmaxscaling to the data.

# %%
# from sklearn.preprocessing import MinMaxScaler
# minmax = MinMaxScaler()

# data1 = pd.DataFrame()
# data1[data.columns] = minmax.fit_transform(data)
# data1

# %%
data.skew()
#Allowable range is from -2 to +2
# Out:
# Close    0.404251
# dtype: float64

# %%
data.kurt()
#Allowable range is from -7 to +7
# Out:
# Close   -1.273738
# dtype: float64

# %% [markdown]
# ## Visualization

# %% [markdown]
# https://colab.research.google.com/drive/1M9oLQgGiBubg6LK3XSraJoSyniNMht3_#scrollTo=bxuyYmJVTaUT

# %% [markdown]
# ## Model Building

# %%
data
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2023-02-07  2305.899902
# 2023-02-08  2351.949951
# 2023-02-09  2356.050049
# 2023-02-10  2336.649902
# 2023-02-13  2323.350098
#
# [2006 rows x 1 columns]

# %%
data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Mean & Rolling Standard deviation

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    #Plot rolling statistics:
    plt.plot(timeseries, color='yellow',label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show(block=False)
    print("Results of AD-fuller test")
    adft = adfuller(timeseries,autolag='AIC')
    # output for dft will give us without defining what the values are.
    #hence we manually write what values does it explains using a for loop
    output = pd.Series(adft[0:4],index=['Test Statistics','p-value','No. of lags used','Number of observations used'])
    for key,values in adft[4].items():
        output['critical value (%s)'%key] =  values
    print(output)

test_stationarity(data)
# Out:
# Results of AD-fuller test
# Test Statistics                  -0.719988
# p-value                           0.841504
# No. of lags used                  5.000000
# Number of observations used    2000.000000
# critical value (1%)              -3.433624
# critical value (5%)              -2.862986
# critical value (10%)             -2.567540
# dtype: float64

# %%
#Ho: It is non stationary
#H1: It is stationary

def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %% [markdown]
# ## Seasonal Decompositions

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(data, model='multiplicative',period = 30)
fig = plt.figure()  
fig = result.plot()  
fig.set_size_inches(16, 9)

# %% [markdown]
# For time series analysis we separate Trend and Seasonality from the time series.

# %% [markdown]
# ## Logarithmic model

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
df_log = np.log(data)
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()
plt.legend(loc='best')
plt.title('Moving Average')
plt.plot(std_dev, color ="black", label = "Standard Deviation")
plt.plot(moving_avg, color="red", label = "Mean")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Train & Test Split

# %%
train=data[(data['Close'].index.get_level_values(0)>='2015-01-01')&(data['Close'].index.get_level_values(0)<='2020-01-01')]
test=data[(data['Close'].index.get_level_values(0)>'2020-01-01')]
plt.figure(figsize=(10,6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Closing Prices')
plt.plot(train, 'green', label='Train data')
plt.plot(test, 'blue', label='Test data')
plt.legend()

# %%
train
# Out:
#                   Close
# Date
# 2015-01-01   439.781311
# 2015-01-02   438.617340
# 2015-01-05   433.812897
# 2015-01-06   414.124512
# 2015-01-07   423.139069
# ...                 ...
# 2019-12-26  1501.170410
# 2019-12-27  1527.867310
# 2019-12-30  1529.699951
# 2019-12-31  1499.833130
# 2020-01-01  1495.424927
#
# [1230 rows x 1 columns]

# %%
test.shape
# Out:
# (776, 1)

# %% [markdown]
# ## Shift Model

# %%
data['Close First Difference'] = data['Close'] - data['Close'].shift(12)

# %%
data['Close'].shift(12)
# Out:
# Date
# 2015-01-01            NaN
# 2015-01-02            NaN
# 2015-01-05            NaN
# 2015-01-06            NaN
# 2015-01-07            NaN
#                  ...
# 2023-02-07    2472.050049
# 2023-02-08    2442.649902
# 2023-02-09    2430.300049
# 2023-02-10    2415.949951
# 2023-02-13    2382.550049
# Name: Close, Length: 2006, dtype: float64

# %%
data.head(14)
# Out:
#                  Close  Close First Difference
# Date
# 2015-01-01  439.781311                     NaN
# 2015-01-02  438.617340                     NaN
# 2015-01-05  433.812897                     NaN
# 2015-01-06  414.124512                     NaN
# 2015-01-07  423.139069                     NaN
# 2015-01-08  417.071564                     NaN
# 2015-01-09  426.110901                     NaN
# 2015-01-12  421.157837                     NaN
# 2015-01-13  417.616425                     NaN
# 2015-01-14  413.554901                     NaN
# 2015-01-15  428.067352                     NaN
# 2015-01-16  430.766754                     NaN
# 2015-01-19  435.695038               -4.086273
# 2015-01-20  447.285187                8.667847

# %%
## Again test dickey fuller test
adfuller_test(data['Close First Difference'].dropna())
# Out:
# ADF Test Statistic : -7.432316700969164
# p-value : 6.313348031822149e-11
# #Lags Used : 26
# Number of Observations Used : 1967
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# ##  ARIMA Model

# %%
# # For non-seasonal data
# #p=1, d=1, q=0 or 1
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(data['Close'],order=(1,1,1))
model_fit=model.fit()
# Out:
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
model_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  Close   No. Observations:                 2006
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -9463.409
# Date:                Tue, 14 Feb 2023   AIC                          18932.818
# Time:                        00:22:34   BIC                          18949.628
# Sample:                             0   HQIC                         18938.989
#                                - 2006
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.4971      1.929     -0.258      0.797      -4.278       3.284
# ma.L1          0.5019      1.922      0.261      0.794      -3.265       4.269
# sigma2       737.1806     11.145     66.147      0.000     715.338     759.023
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.57   Jarque-Bera (JB):              4037.66
# Prob(Q):                              0.45   Prob(JB):                         0.00
# Heteroskedasticity (H):              22.01   Skew:                             0.03
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
data['forecast']=model_fit.predict(start=1620,end=1980,dynamic=True)
data[['Close','forecast']].plot(figsize=(18,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## SARIMAX Model

# %%
model=sm.tsa.statespace.SARIMAX(data['Close'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
data['forecast']=results.predict(start=1620,end=1980,dynamic=True)
data[['Close','forecast']].plot(figsize=(12,8))
# Out:
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <AxesSubplot:xlabel='Date'>

# %%
results.save("Sarimax.pkl")

# %%
from pandas.tseries.offsets import DateOffset
future_dates=[data.index[-1]+ DateOffset(days=x)for x in range(0,21)]
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=data.columns)

future_datest_df.tail()

future_df=pd.concat([data,future_datest_df])

future_df['forecast'] = results.predict(start = 1620, end = 1985, typ='levels')
future_df[['Close', 'forecast']].plot(figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %%
predictions=results.predict(start=1988,end=2018,typ='levels')
predictions.shape
# Out:
# C:\Users\POURNIMA\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# (31,)

# %%
from datetime import timedelta, date
Date_req = date.today() + timedelta(days=31)
# Date_req

index_future_dates=pd.date_range(start=datetime.today(),end=Date_req)
a = len(data)
predictions.index=index_future_dates
print(predictions)
# Out:
# 2023-02-14 00:22:40.242060    2478.866159
# 2023-02-15 00:22:40.242060    2478.782894
# 2023-02-16 00:22:40.242060    2471.786179
# 2023-02-17 00:22:40.242060    2444.292345
# 2023-02-18 00:22:40.242060    2430.784361
# 2023-02-19 00:22:40.242060    2416.626440
# 2023-02-20 00:22:40.242060    2382.098949
# 2023-02-21 00:22:40.242060    2333.376856
# 2023-02-22 00:22:40.242060    2358.913169
# 2023-02-23 00:22:40.242060    2355.913157
# 2023-02-24 00:22:40.242060    2340.462812
# 2023-02-25 00:22:40.242060    2330.792860
# 2023-02-26 00:22:40.242060    2327.943414
# 2023-02-27 00:22:40.242060    2315.234909
# 2023-02-28 00:22:40.242060    2305.420318
# 2023-03-01 00:22:40.242060    2355.244922
# 2023-03-02 00:22:40.242060    2356.709421
# 2023-03-03 00:22:40.242060    2336.154416
# 2023-03-04 00:22:40.242060    2323.066991
# 2023-03-05 00:22:40.242060    2320.961399
# 2023-03-06 00:22:40.242060    2320.122257
# 2023-03-07 00:22:40.242060    2322.040152
# 2023-03-08 00:22:40.242060    2323.021852
# 2023-03-09 00:22:40.242060    2326.914633
# 2023-03-10 00:22:40.242060    2325.726403
# 2023-03-11 00:22:40.242060    2329.840380
# 2023-03-12 00:22:40.242060    2330.688428
# 2023-03-13 00:22:40.242060    2333.072604
# 2023-03-14 00:22:40.242060    2333.373551
# 2023-03-15 00:22:40.242060    2333.458398
# 2023-03-16 00:22:40.242060    2334.005067
# Freq: D, Name: predicted_mean, dtype: float64

# %%
predictions.to_csv("Predictions.csv")

# %%
new_pred = pd.concat([data,predictions], axis=1)
new_pred
# Out:
#                                  Close  Close First Difference  forecast  \
# 2015-01-01 00:00:00.000000  439.781311                     NaN       NaN
# 2015-01-02 00:00:00.000000  438.617340                     NaN       NaN
# 2015-01-05 00:00:00.000000  433.812897                     NaN       NaN
# 2015-01-06 00:00:00.000000  414.124512                     NaN       NaN
# 2015-01-07 00:00:00.000000  423.139069                     NaN       NaN
# ...                                ...                     ...       ...
# 2023-03-12 00:22:40.242060         NaN                     NaN       NaN
# 2023-03-13 00:22:40.242060         NaN                     NaN       NaN
# 2023-03-14 00:22:40.242060         NaN                     NaN       NaN
# 2023-03-15 00:22:40.242060         NaN                     NaN       NaN
# 2023-03-16 00:22:40.242060         NaN                     NaN       NaN
#
#                             predicted_mean
# 2015-01-01 00:00:00.000000             NaN
# 2015-01-02 00:00:00.000000             NaN
# 2015-01-05 00:00:00.000000             NaN
# 2015-01-06 00:00:00.000000             NaN
# 2015-01-07 00:00:00.000000             NaN
# ...                                    ...
# 2023-03-12 00:22:40.242060     2330.688428
# 2023-03-13 00:22:40.242060     2333.072604
# 2023-03-14 00:22:40.242060     2333.373551
# 2023-03-15 00:22:40.242060     2333.458398
# 2023-03-16 00:22:40.242060     2334.005067
#
# [2037 rows x 4 columns]

# %%
from datetime import datetime
d = new_pred.index
new_pred.index = d.strftime('%Y-%m-%d')

# %%
new_pred
# Out:
#                  Close  Close First Difference  forecast  predicted_mean
# 2015-01-01  439.781311                     NaN       NaN             NaN
# 2015-01-02  438.617340                     NaN       NaN             NaN
# 2015-01-05  433.812897                     NaN       NaN             NaN
# 2015-01-06  414.124512                     NaN       NaN             NaN
# 2015-01-07  423.139069                     NaN       NaN             NaN
# ...                ...                     ...       ...             ...
# 2023-03-12         NaN                     NaN       NaN     2330.688428
# 2023-03-13         NaN                     NaN       NaN     2333.072604
# 2023-03-14         NaN                     NaN       NaN     2333.373551
# 2023-03-15         NaN                     NaN       NaN     2333.458398
# 2023-03-16         NaN                     NaN       NaN     2334.005067
#
# [2037 rows x 4 columns]

# %%
new_pred.drop(['Close First Difference','forecast'],axis=1,inplace=True)
new_pred
# Out:
#                  Close  predicted_mean
# 2015-01-01  439.781311             NaN
# 2015-01-02  438.617340             NaN
# 2015-01-05  433.812897             NaN
# 2015-01-06  414.124512             NaN
# 2015-01-07  423.139069             NaN
# ...                ...             ...
# 2023-03-12         NaN     2330.688428
# 2023-03-13         NaN     2333.072604
# 2023-03-14         NaN     2333.373551
# 2023-03-15         NaN     2333.458398
# 2023-03-16         NaN     2334.005067
#
# [2037 rows x 2 columns]

# %%
plt.figure(figsize=(30,15))
plt.plot(new_pred)
# Out:
# [<matplotlib.lines.Line2D at 0x20c9fe669d0>,
#  <matplotlib.lines.Line2D at 0x20c9fe663a0>]

# %%
plt.figure(figsize=(30,8))
plt.xticks(rotation='vertical')
plt.plot(new_pred[1958:2037])
# Out:
# [<matplotlib.lines.Line2D at 0x20cb93972b0>,
#  <matplotlib.lines.Line2D at 0x20cb9397220>]

# %%
new_pred[-60:]
# Out:
#                   Close  predicted_mean
# 2023-01-03  2557.050049             NaN
# 2023-01-04  2518.550049             NaN
# 2023-01-05  2514.050049             NaN
# 2023-01-06  2536.899902             NaN
# 2023-01-09  2596.800049             NaN
# 2023-01-10  2558.399902             NaN
# 2023-01-11  2526.149902             NaN
# 2023-01-12  2471.600098             NaN
# 2023-01-13  2467.600098             NaN
# 2023-01-16  2444.100098             NaN
# 2023-01-17  2478.800049             NaN
# 2023-01-18  2474.699951             NaN
# 2023-01-19  2472.050049             NaN
# 2023-01-20  2442.649902             NaN
# 2023-01-23  2430.300049             NaN
# 2023-01-24  2415.949951             NaN
# 2023-01-25  2382.550049             NaN
# 2023-01-27  2337.350098             NaN
# 2023-01-30  2359.750000             NaN
# 2023-01-31  2353.850098             NaN
# 2023-02-01  2339.899902             NaN
# 2023-02-02  2326.949951             NaN
# 2023-02-03  2329.000000             NaN
# 2023-02-06  2311.449951             NaN
# 2023-02-07  2305.899902             NaN
# 2023-02-08  2351.949951             NaN
# 2023-02-09  2356.050049             NaN
# 2023-02-10  2336.649902             NaN
# 2023-02-13  2323.350098             NaN
# 2023-02-14          NaN     2478.866159
# 2023-02-15          NaN     2478.782894
# 2023-02-16          NaN     2471.786179
# 2023-02-17          NaN     2444.292345
# 2023-02-18          NaN     2430.784361
# 2023-02-19          NaN     2416.626440
# 2023-02-20          NaN     2382.098949
# 2023-02-21          NaN     2333.376856
# 2023-02-22          NaN     2358.913169
# 2023-02-23          NaN     2355.913157
# 2023-02-24          NaN     2340.462812
# 2023-02-25          NaN     2330.792860
# 2023-02-26          NaN     2327.943414
# 2023-02-27          NaN     2315.234909
# 2023-02-28          NaN     2305.420318
# 2023-03-01          NaN     2355.244922
# 2023-03-02          NaN     2356.709421
# 2023-03-03          NaN     2336.154416
# 2023-03-04          NaN     2323.066991
# 2023-03-05          NaN     2320.961399
# 2023-03-06          NaN     2320.122257
# 2023-03-07          NaN     2322.040152
# 2023-03-08          NaN     2323.021852
# 2023-03-09          NaN     2326.914633
# 2023-03-10          NaN     2325.726403
# 2023-03-11          NaN     2329.840380
# 2023-03-12          NaN     2330.688428
# 2023-03-13          NaN     2333.072604
# 2023-03-14          NaN     2333.373551
# 2023-03-15          NaN     2333.458398
# 2023-03-16          NaN     2334.005067

# %%
moving_averages = pd.DataFrame()
plt.figure(figsize=(15,8))
moving_averages['SMA 100'] = data['Close'].rolling(100).mean()
moving_averages['EMA 100'] = data['Close'].ewm(span=100).mean()
moving_averages['Close Prices'] = data['Close']
plt.plot(moving_averages['Close Prices'], color='lightblue', label='Daily Close Price')
plt.plot(moving_averages['SMA 100'], color='green', label='SMA 100')
plt.plot(moving_averages['EMA 100'], color='red', label='EMA 100')
plt.legend()
